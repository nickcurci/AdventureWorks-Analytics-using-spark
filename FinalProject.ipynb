# %% [markdown]
# ![image.png](attachment:image.png)
# # <center>AdventureWorks Analytics Dashboard Project</center>
#
# Useful link:
#
# https://stackoverflow.com/questions/29226210/what-is-the-spark-dataframe-method-topandas-actually-doing

# %% [markdown]
# ## Create a Spark Cluster to run your notebook on.

# %% [markdown]
# ## You should already have uploaded the data into Databricks as tables.

# %% [markdown]
# ## Create the Dashboard Widgets...
# See link for documentation: https://docs.databricks.com/user-guide/notebooks/widgets.html

# %%
dbutils.widgets.removeAll()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql describe  factinternetsales
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>ProductKey</td><td>int</td><td>null</td></tr><tr><td>OrderDateKey</td><td>int</td><td>null</td></tr><tr><td>DueDateKey</td><td>int</td><td>null</td></tr><tr><td>ShipDateKey</td><td>int</td><td>null</td></tr><tr><td>CustomerKey</td><td>int</td><td>null</td></tr><tr><td>PromotionKey</td><td>int</td><td>null</td></tr><tr><td>CurrencyKey</td><td>int</td><td>null</td></tr><tr><td>SalesTerritoryKey</td><td>int</td><td>null</td></tr><tr><td>SalesOrderNumber</td><td>string</td><td>null</td></tr><tr><td>SalesOrderLineNumber</td><td>int</td><td>null</td></tr><tr><td>RevisionNumber</td><td>int</td><td>null</td></tr><tr><td>OrderQuantity</td><td>int</td><td>null</td></tr><tr><td>UnitPrice</td><td>double</td><td>null</td></tr><tr><td>ExtendedAmount</td><td>double</td><td>null</td></tr><tr><td>UnitPriceDiscountPct</td><td>int</td><td>null</td></tr><tr><td>DiscountAmount</td><td>int</td><td>null</td></tr><tr><td>ProductStandardCost</td><td>double</td><td>null</td></tr><tr><td>TotalProductCost</td><td>double</td><td>null</td></tr><tr><td>SalesAmount</td><td>double</td><td>null</td></tr><tr><td>TaxAmt</td><td>double</td><td>null</td></tr><tr><td>Freight</td><td>double</td><td>null</td></tr><tr><td>CarrierTrackingNumber</td><td>string</td><td>null</td></tr><tr><td>CustomerPONumber</td><td>string</td><td>null</td></tr><tr><td>OrderDate</td><td>timestamp</td><td>null</td></tr><tr><td>DueDate</td><td>timestamp</td><td>null</td></tr><tr><td>ShipDate</td><td>timestamp</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# # Create Widgets...

# %% [markdown]
# ## 1) Create the following Notbeook Widgets...
#
# - Drop Down List named FiscalYear that is loaded dynamically from the unique FiscalYear values in factinternetsales.  (You will need to join to dimdate) Default to "2014"
# - Drop Down List named Country that is loaded dynmically from the unique list of EnglishCountryRegionName values in dimgeography. Default to "United Sates".
# - Drop Down list named Category that is loaded dynamically from the unqiue ProductCategory values in dimproductcategory. Default to 'Bikes'

# %%
# %sql 
CREATE WIDGET DROPDOWN FiscalYear DEFAULT "2013" CHOICES 
select distinct FiscalYear 
from factinternetsales f
inner join dimdate d 
on  f.orderdatekey = d.datekey 
order by fiscalyear
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
CREATE WIDGET DROPDOWN Country DEFAULT "United States" CHOICES 
select distinct EnglishCountryRegionName
from dimgeography
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql 
CREATE WIDGET DROPDOWN Category DEFAULT "Bikes" CHOICES 
select distinct EnglishProductCategoryName
from dimproductcategory
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ### 2) For product analysis, it will be a lot easier if we can get the Product information together, i.e. we want to have the product category, product subcategory, and product information together.  Lets create a SQL view that gives us these columns with the keys so we can easily do queries with them.  Note:  This is a good example of denormalizing data to make it easier to query.
#
# #### Create a SQL view called *vproductinfo* that contains the following columns:
#
# - ProductCategoryKey from dimproductcategory
# - ProductSubcategoryKey from dimproductsubcategory
# - ProductKey from dimproduct
# - EnglishProductCategoryName renamed as Category from dimproductcategory
# - EnglishProductSubcategoryName renamed as Subcategory from improductsubcategory
# - ModelName as Model from dimproduct

# %%
# %sql
CREATE OR REPLACE VIEW vproductinfo
  AS
Select DPC.ProductCategoryKey, DPSC.productsubcategorykey, DP.ProductKey, dpc.EnglishProductCategoryName as Category,DPSC.EnglishProductSubcategoryName as Subcategory, dp.ModelName as Model
from dimproductcategory DPC
inner join dimproductsubcategory DPSC on DPC.ProductCategoryKey = DPSC.ProductCategoryKey 
inner join dimproduct DP on DP.ProductSubcategoryKey = DPSC.productsubcategorykey
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from vproductinfo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ProductCategoryKey</th><th>productsubcategorykey</th><th>ProductKey</th><th>Category</th><th>Subcategory</th><th>Model</th></tr></thead><tbody><tr><td>2</td><td>14</td><td>210</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>211</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>4</td><td>31</td><td>212</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>4</td><td>31</td><td>213</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>4</td><td>31</td><td>214</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>4</td><td>31</td><td>215</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>4</td><td>31</td><td>216</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>4</td><td>31</td><td>217</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>3</td><td>23</td><td>218</td><td>Clothing</td><td>Socks</td><td>Mountain Bike Socks</td></tr><tr><td>3</td><td>23</td><td>219</td><td>Clothing</td><td>Socks</td><td>Mountain Bike Socks</td></tr><tr><td>4</td><td>31</td><td>220</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>4</td><td>31</td><td>221</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>4</td><td>31</td><td>222</td><td>Accessories</td><td>Helmets</td><td>Sport-100</td></tr><tr><td>3</td><td>19</td><td>223</td><td>Clothing</td><td>Caps</td><td>Cycling Cap</td></tr><tr><td>3</td><td>19</td><td>224</td><td>Clothing</td><td>Caps</td><td>Cycling Cap</td></tr><tr><td>3</td><td>19</td><td>225</td><td>Clothing</td><td>Caps</td><td>Cycling Cap</td></tr><tr><td>3</td><td>21</td><td>226</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>227</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>228</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>229</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>230</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>231</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>232</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>233</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>234</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>235</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>236</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>3</td><td>21</td><td>237</td><td>Clothing</td><td>Jerseys</td><td>Long-Sleeve Logo Jersey</td></tr><tr><td>2</td><td>14</td><td>238</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>239</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>240</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>241</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>242</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>243</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>244</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>245</td><td>Components</td><td>Road Frames</td><td>HL Road Frame</td></tr><tr><td>2</td><td>14</td><td>246</td><td>Components</td><td>Road Frames</td><td>HL ...

# %% [markdown]
# ## 3 A)  Create a SQL view named vsalesinfo that contains the followig data.
# - SalesAmount from factinternetsales
# - All the columns from vproductinfo (the view we created earlier)
# - from dimcustomer, get EnglishEductionLevel renamed as Education
# - from dimcustomer, get Gender
# - from dimcustomer, get YearlyIncome as Salary
# - from dimcustomer, if the customer has any children (NumberChildrenAtHome > 0), set to 'Y', else set to 'N' and call this column 'HasChildren'
# - from dimcustomer, get HomeOwnerFlag as HomeOwner
# - from dimcustomer, AgeBand as
# ``` CASE  WHEN age < 18 then 'Minor'
#                        WHEN age between 19 and 29 then 'Young'
#                        WHEN age between 30 and 39 then 'Middle'
#                        WHEN age between 40 and 49 then 'Late Middle'
#                        WHEN age > 50 then 'Golden'
#                        ELSE 'Other' END as AgeBand"
# ```

# %%
# %sql
describe dimcustomer
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>CustomerKey</td><td>int</td><td>null</td></tr><tr><td>GeographyKey</td><td>int</td><td>null</td></tr><tr><td>CustomerAlternateKey</td><td>string</td><td>null</td></tr><tr><td>Title</td><td>string</td><td>null</td></tr><tr><td>FirstName</td><td>string</td><td>null</td></tr><tr><td>MiddleName</td><td>string</td><td>null</td></tr><tr><td>LastName</td><td>string</td><td>null</td></tr><tr><td>NameStyle</td><td>int</td><td>null</td></tr><tr><td>BirthDate</td><td>timestamp</td><td>null</td></tr><tr><td>MaritalStatus</td><td>string</td><td>null</td></tr><tr><td>Suffix</td><td>string</td><td>null</td></tr><tr><td>Gender</td><td>string</td><td>null</td></tr><tr><td>EmailAddress</td><td>string</td><td>null</td></tr><tr><td>YearlyIncome</td><td>double</td><td>null</td></tr><tr><td>TotalChildren</td><td>int</td><td>null</td></tr><tr><td>NumberChildrenAtHome</td><td>int</td><td>null</td></tr><tr><td>EnglishEducation</td><td>string</td><td>null</td></tr><tr><td>SpanishEducation</td><td>string</td><td>null</td></tr><tr><td>FrenchEducation</td><td>string</td><td>null</td></tr><tr><td>EnglishOccupation</td><td>string</td><td>null</td></tr><tr><td>SpanishOccupation</td><td>string</td><td>null</td></tr><tr><td>FrenchOccupation</td><td>string</td><td>null</td></tr><tr><td>HouseOwnerFlag</td><td>int</td><td>null</td></tr><tr><td>NumberCarsOwned</td><td>int</td><td>null</td></tr><tr><td>AddressLine1</td><td>string</td><td>null</td></tr><tr><td>AddressLine2</td><td>string</td><td>null</td></tr><tr><td>Phone</td><td>string</td><td>null</td></tr><tr><td>DateFirstPurchase</td><td>timestamp</td><td>null</td></tr><tr><td>CommuteDistance</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE VIEW vdimcustomer as
select *, int((DATEDIFF(CURRENT_DATE, birthdate))/365) as age from dimcustomer;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql

CREATE OR REPLACE VIEW vsalesinfo as

Select FIS.SalesAmount, VPI.* , VC.EnglishEducAtion as Education, VC.Gender, VC.YearlyIncome as Salary, 

CASE WHEN NumberChildrenAtHome > 0 then  'y'
     else 'n' END AS HasChildren , 

VC.HouseOwnerFlag as HomeOwner,
              
CASE WHEN VC.age < 18 then 'Minor'
     WHEN VC.age between 19 and 29 then 'Young'
     WHEN VC.age between 30 and 39 then 'Middle'
     WHEN VC.age between 40 and 49 then 'Late Middle'
     WHEN VC.age > 50 then 'Golden'
     ELSE 'Other' END as AgeBand
                 
                 
from vdimcustomer VC
inner join factinternetsales FIS 
on (FIS.CustomerKey = VC.CustomerKey)
inner join vproductinfo VPI
on (FIS.ProductKey= VPI.ProductKey)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
describe vsalesinfo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>SalesAmount</td><td>double</td><td>null</td></tr><tr><td>ProductCategoryKey</td><td>int</td><td>null</td></tr><tr><td>productsubcategorykey</td><td>int</td><td>null</td></tr><tr><td>ProductKey</td><td>int</td><td>null</td></tr><tr><td>Category</td><td>string</td><td>null</td></tr><tr><td>Subcategory</td><td>string</td><td>null</td></tr><tr><td>Model</td><td>string</td><td>null</td></tr><tr><td>Education</td><td>string</td><td>null</td></tr><tr><td>Gender</td><td>string</td><td>null</td></tr><tr><td>Salary</td><td>double</td><td>null</td></tr><tr><td>HasChildren</td><td>string</td><td>null</td></tr><tr><td>HomeOwner</td><td>int</td><td>null</td></tr><tr><td>AgeBand</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select * from vsalesinfo
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesAmount</th><th>ProductCategoryKey</th><th>productsubcategorykey</th><th>ProductKey</th><th>Category</th><th>Subcategory</th><th>Model</th><th>Education</th><th>Gender</th><th>Salary</th><th>HasChildren</th><th>HomeOwner</th><th>AgeBand</th></tr></thead><tbody><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial College</td><td>F</td><td>60000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial High School</td><td>M</td><td>40000.0</td><td>n</td><td>0</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>M</td><td>20000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>High School</td><td>F</td><td>10000.0</td><td>y</td><td>1</td><td>Late Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Graduate Degree</td><td>M</td><td>70000.0</td><td>n</td><td>0</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Graduate Degree</td><td>F</td><td>30000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>M</td><td>80000.0</td><td>y</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial College</td><td>M</td><td>40000.0</td><td>n</td><td>1</td><td>Late Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>F</td><td>80000.0</td><td>n</td><td>0</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>M</td><td>40000.0</td><td>n</td><td>0</td><td>Late Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial College</td><td>M</td><td>90000.0</td><td>n</td><td>1</td><td>Other</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Graduate Degree</td><td>M</td><td>60000.0</td><td>n</td><td>1</td><td>Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>High School</td><td>M</td><td>10000.0</td><td>y</td><td>0</td><td>Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>High School</td><td>F</td><td>30000.0</td><td>n</td><td>0</td><td>Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial College</td><td>M</td><td>70000.0</td><td>y</td><td>0</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>F</td><td>70000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>M</td><td>70000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Graduate Degree</td><td>F</td><td>40000.0</td><td>n</td><td>1</td><td>Late Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><t ...

# %% [markdown]
# ## 3 B) Use SQL to dipslay the total sales amount by Education and then change the visual to a pie chart.

# %%
# %sql
select sum(salesamount), education 
from vsalesinfo
group by education
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(salesamount)</th><th>education</th></tr></thead><tbody><tr><td>4638026.068600005</td><td>High School</td></tr><tr><td>1636405.2589</td><td>Partial High School</td></tr><tr><td>5460560.251299996</td><td>Graduate Degree</td></tr><tr><td>7723542.884799971</td><td>Partial College</td></tr><tr><td>9900142.757099964</td><td>Bachelors</td></tr></tbody></table></div>

# %% [markdown]
# ## 4) Convert the vsalesinfo view above into a PySpark dataframe. Use the display() function to show the data.

# %%
vsalesinfo_df = sqlContext.sql("SELECT * FROM vsalesinfo")
display(vsalesinfo_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesAmount</th><th>ProductCategoryKey</th><th>productsubcategorykey</th><th>ProductKey</th><th>Category</th><th>Subcategory</th><th>Model</th><th>Education</th><th>Gender</th><th>Salary</th><th>HasChildren</th><th>HomeOwner</th><th>AgeBand</th></tr></thead><tbody><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial College</td><td>F</td><td>60000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial High School</td><td>M</td><td>40000.0</td><td>n</td><td>0</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>M</td><td>20000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>High School</td><td>F</td><td>10000.0</td><td>y</td><td>1</td><td>Late Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Graduate Degree</td><td>M</td><td>70000.0</td><td>n</td><td>0</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Graduate Degree</td><td>F</td><td>30000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>M</td><td>80000.0</td><td>y</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial College</td><td>M</td><td>40000.0</td><td>n</td><td>1</td><td>Late Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>F</td><td>80000.0</td><td>n</td><td>0</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>M</td><td>40000.0</td><td>n</td><td>0</td><td>Late Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial College</td><td>M</td><td>90000.0</td><td>n</td><td>1</td><td>Other</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Graduate Degree</td><td>M</td><td>60000.0</td><td>n</td><td>1</td><td>Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>High School</td><td>M</td><td>10000.0</td><td>y</td><td>0</td><td>Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>High School</td><td>F</td><td>30000.0</td><td>n</td><td>0</td><td>Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Partial College</td><td>M</td><td>70000.0</td><td>y</td><td>0</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>F</td><td>70000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Bachelors</td><td>M</td><td>70000.0</td><td>n</td><td>1</td><td>Golden</td></tr><tr><td>24.49</td><td>3</td><td>20</td><td>463</td><td>Clothing</td><td>Gloves</td><td>Half-Finger Gloves</td><td>Graduate Degree</td><td>F</td><td>40000.0</td><td>n</td><td>1</td><td>Late Middle</td></tr><tr><td>24.49</td><td>3</td><td>20</td><t ...

# %% [markdown]
# ## 5) Use the PySpark dataframe you created in quetion 4 to return total sales by Gender and AgeBand and then display the data as the visual defined below.
#
# ### Hint:  Example: display(diamonds_df.groupBy("color","size").sum("price").orderBy("color","size"))
#
#
# - Adjust the Databricks visual output to show the results as:
# - 2 Pie Charts
# - Slices = total sales by AgeBand
# - Split by Gender, i.e. One pie per Gender.

# %%
display(vsalesinfo_df.groupBy("gender", "ageband").sum("salesamount").orderBy("gender","ageband"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gender</th><th>ageband</th><th>sum(salesamount)</th></tr></thead><tbody><tr><td>F</td><td>Golden</td><td>5657083.636699996</td></tr><tr><td>F</td><td>Late Middle</td><td>5813881.959599994</td></tr><tr><td>F</td><td>Middle</td><td>2935848.652100003</td></tr><tr><td>F</td><td>Other</td><td>406804.4268</td></tr><tr><td>M</td><td>Golden</td><td>5592655.464699994</td></tr><tr><td>M</td><td>Late Middle</td><td>5392964.363299997</td></tr><tr><td>M</td><td>Middle</td><td>3085919.1746000024</td></tr><tr><td>M</td><td>Other</td><td>473519.5429000003</td></tr></tbody></table></div>

# %% [markdown]
# ## 6) Convert the PySpark dataframe from question 5 into a local pandas dataframe and display the few rows using the  head() method.

# %%
vsalesinfo_dfP = vsalesinfo_df.toPandas()
vsalesinfo_dfP.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>
#    SalesAmount  ProductCategoryKey  productsubcategorykey  ProductKey  \
# 0        24.49                   3                     20         463
# 1        24.49                   3                     20         463
# 2        24.49                   3                     20         463
# 3        24.49                   3                     20         463
# 4        24.49                   3                     20         463
#
#    Category Subcategory               Model            Education Gender  \
# 0  Clothing      Gloves  Half-Finger Gloves      Partial College      F
# 1  Clothing      Gloves  Half-Finger Gloves  Partial High School      M
# 2  Clothing      Gloves  Half-Finger Gloves            Bachelors      M
# 3  Clothing      Gloves  Half-Finger Gloves          High School      F
# 4  Clothing      Gloves  Half-Finger Gloves      Graduate Degree      M
#
#     Salary HasChildren  HomeOwner      AgeBand
# 0  60000.0           n          1       Golden
# 1  40000.0           n          0       Golden
# 2  20000.0           n          1       Golden
# 3  10000.0           y          1  Late Middle
# 4  70000.0           n          0       Golden
# </div>

# %% [markdown]
# ## 7) Create a SQL view named vsalesbyproduct that gets the following information.
# - from factinternetsales, get SalesAmount
# - from dimdate, get FiscalYear
# - from dimdate, get FiscalQuarter
# - from vproductinfo, get Category
# - from vproductinfo, get Model

# %%
# %sql
CREATE OR REPLACE VIEW vsalesbyproduct
    AS
Select FIS.SalesAmount, DD.FiscalYear, DD.FiscalQuarter, VPI.Category, VPI.Model
from dimdate DD
inner join factinternetsales FIS
on (FIS.OrderDateKey= DD.DateKey)
inner join vproductinfo VPI 
on (FIS.ProductKey = VPI.ProductKey)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
select * from vsalesbyproduct
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesAmount</th><th>FiscalYear</th><th>FiscalQuarter</th><th>Category</th><th>Model</th></tr></thead><tbody><tr><td>24.49</td><td>2012</td><td>2</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</t ...

# %% [markdown]
# ## 8) Using SQL or Python query that data from the view created in step 7, i.e. vsalesbyproduct, filtering the Category on the widget Category value.  Then change the visual display to a bar chart by FiscalYear, by Model.  The model should display as a separate bar within the FiscalYear.

# %%
# %sql
select * from vsalesbyproduct
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesAmount</th><th>FiscalYear</th><th>FiscalQuarter</th><th>Category</th><th>Model</th></tr></thead><tbody><tr><td>24.49</td><td>2012</td><td>2</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</t ...

# %%
WFiscalYear = dbutils.widgets.get("FiscalYear") 
WCategory = dbutils.widgets.get("Category") 
query = "select * from vsalesbyproduct WHERE Category = '" + WCategory + "' and FiscalYear ='" + WFiscalYear + "'" 
vsalesbyproduct_df = spark.sql(query)
display(vsalesbyproduct_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>SalesAmount</th><th>FiscalYear</th><th>FiscalQuarter</th><th>Category</th><th>Model</th></tr></thead><tbody><tr><td>24.49</td><td>2012</td><td>2</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</td></tr><tr><td>24.49</td><td>2012</td><td>3</td><td>Clothing</td><td>Half-Finger Gloves</t ...

# %% [markdown]
# ## 9) We want to get a visual of total sales amound by FiscalYear/FiscalQuarter together.  However, the Databricks visual does not support multiple columns to be used like this so we need to merge the FiscalYear and FiscalQuarter into one column so it looks like '2013-1', '2013-2'...etc.
#
# ### You will need to convert the FiscalYear and FiscalQuarter into strings using the SQL CAST function as shown below.
#
# select CAST(FiscalYear as varchar(4))||"-"|| CAST(FiscalQuarter as varchar(10)) FiscalYrQtr
#
# You need to complete the above SQL statement below  to get the SalesAmount and Category and add a filter that filters Category to the widget dropdown list.

# %%
# %sql
select RAND(5) as PlaceHolder, CAST(FiscalYear as varchar(4))||"-"|| CAST(FiscalQuarter as varchar(10)) FiscalYrQtr 
from dimdate           d 
GROUP BY FiscalYear, FiscalQuarter 
ORDER BY FiscalYear, FiscalQuarter
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>PlaceHolder</th><th>FiscalYrQtr</th></tr></thead><tbody><tr><td>0.3834317464574418</td><td>2005-3</td></tr><tr><td>0.8717196505227195</td><td>2005-4</td></tr><tr><td>0.3786098361718476</td><td>2006-1</td></tr><tr><td>0.1476668307266371</td><td>2006-2</td></tr><tr><td>0.2065076306035767</td><td>2006-3</td></tr><tr><td>0.04666093516613179</td><td>2006-4</td></tr><tr><td>0.3134176192702436</td><td>2007-1</td></tr><tr><td>0.4176833044008268</td><td>2007-2</td></tr><tr><td>0.7297901464513347</td><td>2007-3</td></tr><tr><td>0.9359607054250594</td><td>2007-4</td></tr><tr><td>0.7950268165702509</td><td>2008-1</td></tr><tr><td>0.01693920892948919</td><td>2008-2</td></tr><tr><td>0.6411908952297819</td><td>2008-3</td></tr><tr><td>0.2608018587199239</td><td>2008-4</td></tr><tr><td>0.9828158281922839</td><td>2009-1</td></tr><tr><td>0.4643086758820505</td><td>2009-2</td></tr><tr><td>0.748698453025968</td><td>2009-3</td></tr><tr><td>0.596800912468464</td><td>2009-4</td></tr><tr><td>0.10925389973342525</td><td>2010-1</td></tr><tr><td>0.7449785097301889</td><td>2010-2</td></tr><tr><td>0.04375351163608421</td><td>2010-3</td></tr><tr><td>0.6891882073023902</td><td>2010-4</td></tr><tr><td>0.2615648431790688</td><td>2011-1</td></tr><tr><td>0.14288751743722528</td><td>2011-2</td></tr><tr><td>0.3067674540856369</td><td>2011-3</td></tr><tr><td>0.2466589794120272</td><td>2011-4</td></tr><tr><td>0.6607611851108446</td><td>2012-1</td></tr><tr><td>0.5585171898044321</td><td>2012-2</td></tr><tr><td>0.4705569376249765</td><td>2012-3</td></tr><tr><td>0.19369846818250636</td><td>2012-4</td></tr><tr><td>0.4240624094913904</td><td>2013-1</td></tr><tr><td>0.714105256846827</td><td>2013-2</td></tr><tr><td>0.8874450461989395</td><td>2013-3</td></tr><tr><td>0.9192437554257711</td><td>2013-4</td></tr><tr><td>0.6660906692673818</td><td>2014-1</td></tr><tr><td>0.5029534413816527</td><td>2014-2</td></tr></tbody></table></div>

# %%
# %sql 
-- FIRST MAKE THIS SELECT QUERY, THEN TURN THE QUERY INTO A VIEW, THEN CREATE A DATAFRAME FROM THE VIEW AND USE AN EMBEDDED SQL STATEMENT TO ADD THE WIDET FEATURE ON THE DASHBOARD -- SEE THE BELOW CELLS!
select sum(fis.salesamount) as TotalSales, DPC.EnglishProductCategoryName, CAST(FiscalYear as varchar(4))||"-"|| CAST(FiscalQuarter as varchar(10)) FiscalYrQtr 
from factinternetsales FIS
inner join dimproduct DP
on(DP.productkey = FIS.productkey)
inner join dimproductsubcategory DPSC
on(DPSC.productsubcategorykey = DP.productsubcategorykey)
inner join dimproductcategory DPC
on(DPC.productcategorykey = DPSC.productcategorykey)
inner join dimdate DD
on(DD.DateKey = FIS.orderdatekey)
group by dpc.EnglishProductCategoryName, FiscalYrQTR
ORDER BY FiscalYrQtr
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TotalSales</th><th>EnglishProductCategoryName</th><th>FiscalYrQtr</th></tr></thead><tbody><tr><td>1421357.4772000024</td><td>Bikes</td><td>2010-3</td></tr><tr><td>1801595.1430000025</td><td>Bikes</td><td>2010-4</td></tr><tr><td>1814387.9894000024</td><td>Bikes</td><td>2011-1</td></tr><tr><td>2081606.3559000017</td><td>Bikes</td><td>2011-2</td></tr><tr><td>1375841.3190999962</td><td>Bikes</td><td>2011-3</td></tr><tr><td>1314373.6479999947</td><td>Bikes</td><td>2011-4</td></tr><tr><td>1454653.0597999939</td><td>Bikes</td><td>2012-1</td></tr><tr><td>1694827.2982999915</td><td>Bikes</td><td>2012-2</td></tr><tr><td>642.7900000000001</td><td>Clothing</td><td>2012-2</td></tr><tr><td>2147.079999999999</td><td>Accessories</td><td>2012-2</td></tr><tr><td>56829.49999999934</td><td>Clothing</td><td>2012-3</td></tr><tr><td>120635.01000000758</td><td>Accessories</td><td>2012-3</td></tr><tr><td>2501481.5300000454</td><td>Bikes</td><td>2012-3</td></tr><tr><td>81385.05000000032</td><td>Clothing</td><td>2012-4</td></tr><tr><td>3720282.8500000034</td><td>Bikes</td><td>2012-4</td></tr><tr><td>172125.58000000406</td><td>Accessories</td><td>2012-4</td></tr><tr><td>4107025.50000019</td><td>Bikes</td><td>2013-1</td></tr><tr><td>86949.58000000175</td><td>Clothing</td><td>2013-1</td></tr><tr><td>176261.97999999693</td><td>Accessories</td><td>2013-1</td></tr><tr><td>199218.9599999924</td><td>Accessories</td><td>2013-2</td></tr><tr><td>98642.32000000251</td><td>Clothing</td><td>2013-2</td></tr><tr><td>5030712.480000267</td><td>Bikes</td><td>2013-2</td></tr><tr><td>15323.369999999932</td><td>Clothing</td><td>2013-3</td></tr><tr><td>30371.350000000777</td><td>Accessories</td><td>2013-3</td></tr></tbody></table></div>

# %%
# %sql
--create a view based on the query, all of the joins were needed because the one of the tables was missing a very imporant foreign key 
--dimproduct, thats why all the inner joins were needed

CREATE OR REPLACE VIEW vTSFYQTR
    AS
select sum(FIS.SalesAmount) as TotalSales, DPC.EnglishProductCategoryName, CAST(FiscalYear as varchar(4))||"-"|| CAST(FiscalQuarter as varchar(10)) FiscalYrQtr 
from factinternetsales FIS 
inner join dimproduct DP 
on(DP.productkey = FIS.productkey) 
inner join dimproductsubcategory DPSC 
on(DPSC.productsubcategorykey = DP.productsubcategorykey) 
inner join dimproductcategory DPC 
on(DPC.productcategorykey = DPSC.productcategorykey) 
inner join dimdate DD 
on(DD.DateKey = FIS.orderdatekey) 
group by dpc.EnglishProductCategoryName, FiscalYrQTR
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
#transform the view into a pyspark df and add the widget feautre to the dataframe
WCategory = dbutils.widgets.get("Category") 
Aquery = "select * from vTSFYQTR WHERE EnglishProductCategoryName = '" + WCategory + "' ORDER BY FiscalYRQTR"
vSBP_df = spark.sql(Aquery)
display(vSBP_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TotalSales</th><th>EnglishProductCategoryName</th><th>FiscalYrQtr</th></tr></thead><tbody><tr><td>642.7900000000001</td><td>Clothing</td><td>2012-2</td></tr><tr><td>56829.49999999934</td><td>Clothing</td><td>2012-3</td></tr><tr><td>81385.05000000032</td><td>Clothing</td><td>2012-4</td></tr><tr><td>86949.58000000175</td><td>Clothing</td><td>2013-1</td></tr><tr><td>98642.32000000251</td><td>Clothing</td><td>2013-2</td></tr><tr><td>15323.369999999932</td><td>Clothing</td><td>2013-3</td></tr></tbody></table></div>

# %% [markdown]
# ## 10) Pin all the visualizations to a new Dashboard named 'AW Exec' and confirm the dashboard functions.
# ## When a widget changes value, the related visualization should be updatred.

# %%
# I seriously cannot believe that I managed to do all of this on my own, it finally clicked!
#Thank you for all of the help this semester, there is no way that i could have completed this without meeting with you and working through some key issues together
#i genuienly did not realize how powerful this software is until today, its amazing
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
